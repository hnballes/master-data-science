# %% [markdown]
# # Plots

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ___

# %% [markdown]
# ## Plots

# %% [markdown]
# - Crea dos array (x e y):
#     - x: 1000 números equiespaciados entre 0 a 3$\pi$
#     - y: Resultado de aplicar la función $f(x) = \frac{1}{2}\sin^2(10 x) + \cos(x)$

# %%
x=np.linspace(0,3*np.pi,1000)

y=((np.sin(10*x)**2)/2)+np.cos(x)

# %% [markdown]
# - Crea un gráfico de y en función de x.

# %%
plt.plot(x, y)

# %% [markdown]
# - Realiza el mismo gráfico anterior pero con una línea discontínua y verde

# %%
plt.plot(x, y,"g--")

# %% [markdown]
# - Añade el título "Función f(x)", y nombra a los ejex "x" e "y"

# %%
plt.plot(x, y,"g--",label="Función f(x)")
plt.legend(loc='f(x)')
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# - Añade una leyenda que diga "f(x)"

# %% [markdown]
# - Crea otro array z:
#     - z: Resultado de aplicar la función $g(x) = \frac{1}{2}\sin(10 x) + \cos^2(x)$

# %%
z=((np.sin(10*x))/2)+np.cos(x)**2

# %% [markdown]
# - Crea un gráfico de dos columnas.
#     - Realiza un plot sencillo de $f(x)$ y de $g(x)$ en cada uno de ellos

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.plot(x, y,"g--",label="Función f(x)")
ax2.plot(x, z,"k-",label="Función g(x)")

# %% [markdown]
# - Dibuja el mismo gráfico anterior pero con un estilo y color de línea diferente en cada uno.

# %% [markdown]
# - Aumenta el gráfico anterior de tamaño.

# %% [markdown]
# - Añade títulos a los ejes de cada figura, "x", "f(x)" y "g(x)"

# %% [markdown]
# - Guardalo en un fichero .png, .jpeg y .pdf.

# %% [markdown]
# - Ahora superpon en la misma figura ambas funciones con una legenda para cada una ('f(x)' y 'g(x)'), un título que diga "f(x) y g(x)", y nombra a los ejes "x" e "y".

# %% [markdown]
# ---

# %% [markdown]
# ## Distributions

# %% [markdown]
# - Crea dos arrays
#     - normal: Un array de 1000 números aleatorios usando una distribución normal
#     - chi: Un array de 1000 números aleatorios usando una distribución $\chi^2$ con 5 grados de libertad.

# %%
normal=np.random.normal(0, 1, size=1000)
chi=np.random.chisquare(5,size=1000)

# %% [markdown]
# - Crea un scatter plot con los array anteriores.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1)
ax1.scatter(normal,chi)
ax2.hist(normal)
ax2.hist(chi)
# Out:
# (array([246., 349., 234., 112.,  26.,  19.,   7.,   4.,   1.,   2.]),
#  array([ 0.06759772,  2.55162646,  5.0356552 ,  7.51968394, 10.00371267,
#         12.48774141, 14.97177015, 17.45579889, 19.93982762, 22.42385636,
#         24.9078851 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# - Crea un subplot de dos filas, y pinta en cada una de ellas un histograma para cada una de las distribuciones. Añade título y etiqueta los ejes como consideres.

# %% [markdown]
# - Ahora superpon ambas distribuciones en un único plot

# %% [markdown]
# ---

# %% [markdown]
# ## Pandas

# %% [markdown]
# - A partir del siguiente dataframe

# %%
s = pd.DataFrame(np.random.randn(100, 4).cumsum(axis=0)+100,
              index=np.arange(0, 100),
             columns=['S1', 'S2', 'S3', 'S4'])
s
# Out:
#             S1          S2          S3          S4
# 0    99.837014   99.753477  101.017088   99.898065
# 1    99.404689  100.177416   98.437544  100.600721
# 2    98.368953  101.710109   97.421988   99.926595
# 3    98.420823  100.773848   97.977899   97.517027
# 4    97.872756  101.395949   99.234816   98.203258
# 5    96.639010   98.326831   99.848769   96.808920
# 6    95.478880   97.988588  100.111102   96.247578
# 7    96.599936   98.522700  100.769694   97.133092
# 8    96.398529  100.563644  102.360443   97.761802
# 9    97.293834  100.598884  103.168104   96.669510
# 10   98.695606   99.064452  100.882615   98.166979
# 11   98.787880  100.251879  101.258040   97.431586
# 12  100.350163  100.101052  101.990917   96.016912
# 13  101.751593   99.753751  100.119470   96.160658
# 14  102.295673   99.953834  100.822659   96.060030
# 15  103.897875   99.732390   99.825994   94.729324
# 16  104.346523  100.928882  100.550187   94.095050
# 17  105.656501   99.468440  101.112111   93.748242
# 18  105.966484   98.795203  100.855654   94.089245
# 19  105.790580   99.004804   99.876782   94.399085
# 20  105.594752   98.863170  101.031251   94.993613
# 21  105.323796   98.910060  102.908972   96.399117
# 22  104.729189   99.379584  102.290058   96.707862
# 23  104.917613   98.932942  100.548075   97.346225
# 24  104.616183  100.077486  102.705507   97.157391
# 25  106.250935  100.685028  104.163857   95.501409
# 26  107.992277  101.322034  105.808534   96.137399
# 27  108.617715  101.458778  105.279601   95.753794
# 28  110.810535   99.107848  104.641456   94.875136
# 29  110.696328  102.598971  103.542395   95.476151
# ..         ...         ...         ...         ...
# 70  104.174012  101.171118  100.436287   96.289928
# 71  104.660494  101.956138  100.682538   96.141840
# 72  103.529661  100.010905   98.104290   94.985376
# 73  105.376664  100.213262   97.848203   94.067845
# 74  106.470196  100.055579   98.652137   94.303859
# 75  107.746786  101.461829   99.773114   95.134531
# 76  107.195528  101.211134   99.469255   95.578291
# 77  107.041294  103.608511  100.829620   95.694587
# 78  106.396736  103.622121  101.294126   97.520845
# 79  106.845736  102.863530  101.918134   97.088723
# 80  106.607531  105.383442  101.126864   97.966346
# 81  105.716472  105.530568  101.621906   98.036724
# 82  106.208052  102.595215  101.537827   98.734488
# 83  106.278918  103.441541  102.603029   99.988326
# 84  107.082660  102.616326  103.435659   98.769263
# 85  106.822892  102.636157  102.110409   96.185131
# 86  105.745124  102.746752  104.050471   96.706558
# 87  106.038515  101.634881  103.251294   96.450581
# 88  105.557535  102.062768  103.503055   95.981886
# 89  105.712001   99.900661  103.863377   96.497378
# 90  105.588224  100.051413  103.726382   96.724329
# 91  106.536605   99.516287  103.300335   97.041608
# 92  107.422685   98.183455  103.927470   96.708447
# 93  108.208258   98.371016  102.271118   95.703357
# 94  105.978164   97.961018  101.840676   94.771533
# 95  105.101446   97.160526  101.081836   95.473574
# 96  105.250194   97.489777   99.936289   96.193861
# 97  105.441987   96.659522   99.171701   96.080093
# 98  104.777025   96.460782  100.268164   95.251453
# 99  105.652305   96.049346  100.597793   94.651766
#
# [100 rows x 4 columns]

# %% [markdown]
# - Pinta todas las series en un úncio plot.

# %% [markdown]
# - Ahora pintalas en plots separados

# %% [markdown]
# - Ahora pinta en un mismo gráfico una de las series anteriores y añade el volumen dado por la serie siguiente

# %%
s['vol'] = pd.Series(np.random.rand(100), index = np.arange(100))*100

# %% [markdown]
# - Mejor separalos en dos plots

# %% [markdown]
# - Hacer plots es como pintar un cuadro, lleva tiempo.
# - [Stock chart plots](https://pythonprogramming.net/advanced-matplotlib-graphing-charting-tutorial/).
