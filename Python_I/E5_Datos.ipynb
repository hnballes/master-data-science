# %% [markdown]
# # Ejercicios Datos

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# ## Parte I

# %% [markdown]
# ### Adquisición y guardado de datos.

# %% [markdown]
# - Lee los datos del fichero train.txt.

# %%
df = pd.read_csv('data/train.csv')

# %% [markdown]
# - Cambia algunos de los datos y escribe el fichero train_mod.csv.

# %%
df[0,0]=2
df.to_csv("train_mod.csv")

# %% [markdown]
# ### Limpieza y preparación de datos.

# %% [markdown]
# - Carga el fichero  train.csv.

# %%
df2=pd.read_csv("data/train.csv")

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# - Elimina todas las filas con NaN.

# %%
df2=df2.dropna()

# %% [markdown]
# - Elimina todos los registros donde la edad sea superior al tercer cuartil de esta.

# %%
df2.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.674426    0.464481
# std     247.052476    0.470725    0.515187   15.643866    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
# Out:
# 1       True
# 3       True
# 6      False
# 10      True
# 11     False
# 21      True
# 23      True
# 27      True
# 52     False
# 54     False
# 62      True
# 66      True
# 75      True
# 88      True
# 92      True
# 96     False
# 97      True
# 102     True
# 110     True
# 118     True
# 123     True
# 124    False
# 136     True
# 137     True
# 139     True
# 148     True
# 151     True
# 170    False
# 174    False
# 177    False
#        ...
# 737     True
# 741     True
# 742     True
# 745    False
# 748     True
# 751     True
# 759     True
# 763     True
# 765    False
# 772    False
# 779     True
# 781     True
# 782     True
# 789     True
# 796    False
# 802     True
# 806     True
# 809     True
# 820    False
# 823     True
# 835     True
# 853     True
# 857    False
# 862    False
# 867     True
# 871     True
# 872     True
# 879    False
# 887     True
# 889     True
# Name: Age, Length: 183, dtype: bool

# %% [markdown]
# ---

# %%
data_q=df2.loc[df2.Age<df2.Age.quantile(q=0.75)]

# %%
data_q
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 10            11         1       3
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 136          137         1       1
# 137          138         0       1
# 139          140         0       1
# 148          149         0       2
# 151          152         1       1
# 183          184         1       2
# 193          194         1       2
# 194          195         1       1
# 205          206         0       3
# ...

# %% [markdown]
# ## Parte II

# %% [markdown]
# ### Operaciones de combinar, juntar y agrupar.

# %% [markdown]
# - Calula el número de pasajeros por clase.

# %%
data_q.[["","PassengerId"]].groupby.("Pclass")
# Out:
#   File "<ipython-input-84-5acd86348d67>", line 1
#     data_q.[["Pclass","PassengerId"]].groupby.("Pclass")
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# - Calula la edad media de los supervivientes y los no supervivientes.

# %%
t=data_q.groupby(["Survived"]).mean()
t.loc[:,"Age"]
# Out:
# Survived
# 0    32.97500
# 1    27.29299
# Name: Age, dtype: float64

# %% [markdown]
# - Calula el porcentage de supervientes por edad.

# %%
data_age= data_q[["Age","Survived"]]
data_age.index=data_q["Age"]


dict_edades={}
for grupo,data_grupo in data_age.groupby(lambda x: x//10*10):
    pct_sur = (data_grupo.Survived == 1).sum() / data_grupo.shape[0]*100
    dict_edades[grupo] = pct_sur
dict_edades
# Out:
# {0.0: 80.0,
#  10.0: 78.94736842105263,
#  20.0: 75.0,
#  30.0: 75.51020408163265,
#  40.0: 43.47826086956522}

# %% [markdown]
# - Crea un gráfico de barras de los datos anteriores.

# %% [markdown]
# - Crea una tabla pivote con supervivientes como índice, la clase como columnas y la media de edad.
